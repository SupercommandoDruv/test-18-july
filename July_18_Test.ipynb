# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('cars.csv')
print('Top 7 rows',df.head(7))
print('Last 3 rows',df.tail(3))
# Out:
# Top 7 rows           Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# 5            Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# 6         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2
# 5     1
# 6     4
# Last 3 rows        Unnamed: 0   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 29   Ferrari Dino  19.7    6  145.0  175  3.62  2.77  15.5   0   1     5     6
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   1     5     8
# ...

# %%
print(df.shape)
# Out:
# (32, 12)

# %%
mean=df['mpg'].mean()
mean
# Out:
# 20.090624999999996

# %%
med=np.median(df['mpg'])
med
# Out:
# 19.2

# %%
df.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
df['mpg'].dtype # dtype of column
# Out:
# dtype('float64')

# %%
df.isnull().sum()  # calculate null value
# Out:
# Unnamed: 0    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   mpg         32 non-null     float64
#  2   cyl         32 non-null     int64
#  3   disp        32 non-null     float64
#  4   hp          32 non-null     int64
#  5   drat        32 non-null     float64
#  6   wt          32 non-null     float64
#  7   qsec        32 non-null     float64
#  8   vs          32 non-null     int64
#  9   am          32 non-null     int64
#  10  gear        32 non-null     int64
#  11  carb        32 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
df.drop('carb',axis=1,inplace=True)

# %%
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.rename(columns={'cyl':'CYL_rename'},inplace=True)

# %%
df.head()
# Out:
#           Unnamed: 0   mpg  CYL_rename   disp   hp  drat     wt   qsec  vs  \
# 0          Mazda RX4  21.0           6  160.0  110  3.90  2.620  16.46   0
# 1      Mazda RX4 Wag  21.0           6  160.0  110  3.90  2.875  17.02   0
# 2         Datsun 710  22.8           4  108.0   93  3.85  2.320  18.61   1
# 3     Hornet 4 Drive  21.4           6  258.0  110  3.08  3.215  19.44   1
# 4  Hornet Sportabout  18.7           8  360.0  175  3.15  3.440  17.02   0
#
#    am  gear
# 0   1     4
# 1   1     4
# 2   1     4
# 3   0     3
# 4   0     3

# %%
df.plot.box(figsize=(8, 6), showmeans=True, grid=True)
# Out:
# <AxesSubplot:>

# %%
q1=df.quantile(.25)
q3=df.quantile(.75)
IQR=q3-q1
IQR
# Out:
# mpg             7.37500
# CYL_rename      4.00000
# disp          205.17500
# hp             83.50000
# drat            0.84000
# wt              1.02875
# qsec            2.00750
# vs              1.00000
# am              1.00000
# gear            1.00000
# dtype: float64

# %%
df1=df
df2=df

# %%
sub=df.iloc[2:5,1:4]

# %%
sub
# Out:
#     mpg  CYL_rename   disp
# 2  22.8           4  108.0
# 3  21.4           6  258.0
# 4  18.7           8  360.0

# %%
dict={'A':[1,2,3,4],'B':['a','b','c','d']}

# %%
dict
# Out:
# {'A': [1, 2, 3, 4], 'B': ['a', 'b', 'c', 'd']}

# %%
dict=pd.DataFrame(dict)

# %%
dict
# Out:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c
# 3  4  d

# %%
s="python is fun programmimg language"
print(s.count('p'))
print(s.capitalize())
# Out:
# 2
# Python is fun programmimg language

# %%
#covariance = it is relation between the coloumns having no limit.
#correlation=  it is relation between the coloumns having limit. use to analize the relation 
#variance is the squar of the distance from mean to each poin
#sd is the root of variance

# %%
series= one dimention
dataframe is multi dimention
